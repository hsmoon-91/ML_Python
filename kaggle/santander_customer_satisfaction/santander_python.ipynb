# %% [markdown]
# #### Dataset Description
# - target는 만족한 고객은 0이고, 만족하지 않은 고객은 1로 코딩되어 있습니다.
#
# - 초기에 불만족스러운 고객을 식별하고 고객의 만족을 향상하기 위한 사전 조치를 취하려고 합니다.

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import VarianceThreshold

# %% [markdown]
# ### 1. data preprocessing

# %% [markdown]
# #### 1. Load the dataset

# %%
train = pd.read_csv('../data/train.csv')
x_test = pd.read_csv('../data/test.csv')

# %% [markdown]
# #### 2. EDA

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76020 entries, 0 to 76019
# Columns: 371 entries, ID to TARGET
# dtypes: float64(111), int64(260)
# memory usage: 215.2 MB

# %%
train.head()
# Out:
#    ID  var3  var15  ...  saldo_medio_var44_ult3          var38  TARGET
# 0   1     2     23  ...                     0.0   39205.170000       0
# 1   3     2     34  ...                     0.0   49278.030000       0
# 2   4     2     23  ...                     0.0   67333.770000       0
# 3   8     2     37  ...                     0.0   64007.970000       0
# 4  10     2     39  ...                     0.0  117310.979016       0
#
# [5 rows x 371 columns]

# %%
train.isnull().values.any()
# Out:
# False

# %%
train.columns
# Out:
# Index(['ID', 'var3', 'var15', 'imp_ent_var16_ult1', 'imp_op_var39_comer_ult1',
#        'imp_op_var39_comer_ult3', 'imp_op_var40_comer_ult1',
#        'imp_op_var40_comer_ult3', 'imp_op_var40_efect_ult1',
#        'imp_op_var40_efect_ult3',
#        ...
#        'saldo_medio_var33_hace2', 'saldo_medio_var33_hace3',
#        'saldo_medio_var33_ult1', 'saldo_medio_var33_ult3',
#        'saldo_medio_var44_hace2', 'saldo_medio_var44_hace3',
#        'saldo_medio_var44_ult1', 'saldo_medio_var44_ult3', 'var38', 'TARGET'],
#       dtype='object', length=371)

# %%
# separate feature and target

x = train.drop(columns=['ID', 'TARGET'], axis=1)
y = train['TARGET']

# %%
x.describe()
# Out:
#                 var3         var15  ...  saldo_medio_var44_ult3         var38
# count   76020.000000  76020.000000  ...            76020.000000  7.602000e+04
# mean    -1523.199277     33.212865  ...               56.614351  1.172358e+05
# std     39033.462364     12.956486  ...             2852.579397  1.826646e+05
# min   -999999.000000      5.000000  ...                0.000000  5.163750e+03
# 25%         2.000000     23.000000  ...                0.000000  6.787061e+04
# 50%         2.000000     28.000000  ...                0.000000  1.064092e+05
# 75%         2.000000     40.000000  ...                0.000000  1.187563e+05
# max       238.000000    105.000000  ...           397884.300000  2.203474e+07
#
# [8 rows x 369 columns]

# %%
pd.unique(y)
# Out:
# array([0, 1], dtype=int64)

# %%
x_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75818 entries, 0 to 75817
# Columns: 370 entries, ID to var38
# dtypes: float64(110), int64(260)
# memory usage: 214.0 MB

# %%
x_test.head()
# Out:
#    ID  var3  var15  ...  saldo_medio_var44_ult1  saldo_medio_var44_ult3      var38
# 0   2     2     32  ...                     0.0                     0.0   40532.10
# 1   5     2     35  ...                     0.0                     0.0   45486.72
# 2   6     2     23  ...                     0.0                     0.0   46993.95
# 3   7     2     24  ...                     0.0                     0.0  187898.61
# 4   9     2     23  ...                     0.0                     0.0   73649.73
#
# [5 rows x 370 columns]

# %%
x_test.isnull().values.any()
# Out:
# False

# %%
x_test.columns
# Out:
# Index(['ID', 'var3', 'var15', 'imp_ent_var16_ult1', 'imp_op_var39_comer_ult1',
#        'imp_op_var39_comer_ult3', 'imp_op_var40_comer_ult1',
#        'imp_op_var40_comer_ult3', 'imp_op_var40_efect_ult1',
#        'imp_op_var40_efect_ult3',
#        ...
#        'saldo_medio_var29_ult3', 'saldo_medio_var33_hace2',
#        'saldo_medio_var33_hace3', 'saldo_medio_var33_ult1',
#        'saldo_medio_var33_ult3', 'saldo_medio_var44_hace2',
#        'saldo_medio_var44_hace3', 'saldo_medio_var44_ult1',
#        'saldo_medio_var44_ult3', 'var38'],
#       dtype='object', length=370)

# %%
# Remove the 'ID' column from the test data
x_test = x_test.drop(columns=['ID'], axis=1)

# %%
x_test.describe()
# Out:
#                 var3         var15  imp_ent_var16_ult1  \
# count   75818.000000  75818.000000        75818.000000
# mean    -1579.955011     33.138832           83.164329
# std     39752.473358     12.932000         1694.873886
# min   -999999.000000      5.000000            0.000000
# 25%         2.000000     23.000000            0.000000
# 50%         2.000000     27.000000            0.000000
# 75%         2.000000     39.000000            0.000000
# max       238.000000    105.000000       240000.000000
#
#        imp_op_var39_comer_ult1  imp_op_var39_comer_ult3  \
# count             75818.000000             75818.000000
# mean                 74.312894               123.136448
# std                 364.211245               606.431562
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# max               21093.960000             47943.960000
#
#        imp_op_var40_comer_ult1  imp_op_var40_comer_ult3  \
# count             75818.000000             75818.000000
# mean                  4.578517                 7.666855
# std                 133.383326               239.701416
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# max               21093.960000             47943.960000
#
#        imp_op_var40_efect_ult1  imp_op_var40_efect_ult3  imp_op_var40_ult1  \
# count             75818.000000             75818.000000       75818.000000
# mean                  0.470645                 0.672444           3.635893
# std                  34.028605                42.336668         129.089127
# min                   0.000000                 0.000000           0.000000
# 25%                   0.000000                 0.000000           0.000000
# 50%                   0.000000                 0.000000           0.000000
# 75%                   0.000000                 0.000000           0.000000
# max                6600.000000              6600.000000       23799.960000
#
#        ...  saldo_medio_var29_ult3  saldo_medio_var33_hace2  \
# count  ...            75818.000000             75818.000000
# mean   ...                0.160595                12.438559
# std    ...               32.441677               958.651673
# min    ...                0.000000                 0.000000
# 25%    ...                0.000000                 0.000000
# 50%    ...                0.000000                 0.000000
# 75%    ...                0.000000                 0.000000
# max    ...             8030.160000            146605.320000
#
#        saldo_medio_var33_hace3  saldo_medio_var33_ult1  \
# count             75818.000000            75818.000000
# mean                  1.327408               17.469991
# std                 170.449935             1252.618781
# min                   0.000000               -0.600000
# 25%                   0.000000                0.000000
# 50%                   0.000000                0.000000
# 75%                   0.000000                0.000000
# max               40080.600000           162355.800000
#
#        saldo_medio_var33_ult3  saldo_medio_var44_hace2  \
# count            75818.000000             75818.000000
# mean                12.674349                63.597839
# std                895.165516              3754.668954
# min                 -0.600000                 0.000000
# 25%                  0.000000                 0.000000
# 50%                  0.000000                 0.000000
# 75%                  0.000000                 0.000000
# max             138054.960000            453893.400000
#
#        saldo_medio_var44_hace3  saldo_medio_var44_ult1  \
# count             75818.000000            75818.000000
# mean                 11.404505               95.973025
# std                1061.858193             4658.871575
# min                   0.000000                0.000000
# 25%                   0.000000                0.000000
# 50%                   0.000000                0.000000
# 75%                   0.000000                0.000000
# max              217762.230000           496198.080000
#
#        saldo_medio_var44_ult3         var38
# count            75818.000000  7.581800e+04
# mean                70.504319  1.173863e+05
# std               3318.527783  2.479384e+05
# min                  0.000000  1.202730e+03
# 25%                  0.000000  6.754961e+04
# 50%                  0.000000  1.057643e+05
# 75%                  0.000000  1.183159e+05
# max             354260.730000  2.889440e+07
#
# [8 rows x 369 columns]

# %%
cols = ['var3', 'var15', 'imp_ent_var16_ult1', 'imp_op_var39_comer_ult1']

# create the figure and axes
fig, axes = plt.subplots(2, 2)
axes = axes.ravel()  # flattening the array makes indexing easier

for col, ax in zip(cols, axes):
    sns.histplot(data=train[col], kde=True, stat='density', ax=ax)

fig.tight_layout()
plt.show()

# %%
# Normalize feature (pd -> np)
ss = StandardScaler()
x = ss.fit_transform(x)
x_test_normalized = ss.transform(x_test)

# %%
np.mean(x, axis=1)
# Out:
# array([-0.10089958,  0.05329292, -0.06425513, ..., -0.06624193,
#        -0.05981906, -0.09492999])

# %%
np.max(x, axis=1)
# Out:
# array([1.23623193, 5.96855119, 1.23623193, ..., 1.23623193, 1.23623193,
#        1.23623193])

# %%
np.mean(x_test_normalized, axis=1)
# Out:
# array([-0.06069201, -0.09664953, -0.04475034, ..., -0.05869041,
#        -0.06168446, -0.0651164 ])

# %%
constant_filter = VarianceThreshold(threshold=0.01)
x_filtered = constant_filter.fit_transform(x)
x_test_filtered = constant_filter.transform(x_test_normalized)

# %%
np.mean(x_filtered, axis=1)
# Out:
# array([-0.11114013,  0.05870176, -0.07077655, ..., -0.07296499,
#        -0.06589024, -0.10456468])

# %%
np.mean(x_test_filtered, axis=1)
# Out:
# array([-0.06685179, -0.10645874, -0.04929216, ..., -0.06464705,
#        -0.06794497, -0.07172523])

# %%
# 생략없이 출력값 출력하기
# np.set_printoptions(threshold=np.inf, linewidth=np.inf)

# %% [markdown]
# #### 3. data split

# %%
# Split the data into training set and validation set
x_train, x_val, y_train, y_val = train_test_split(x_filtered, y, train_size=0.80, random_state=0)

# %%
x_train
# Out:
# array([[ 0.0390744 , -0.78824863, -0.0533881 , ..., -0.01881691,
#         -0.01984685,  0.07053165],
#        [ 0.0390744 , -0.63388477, -0.0533881 , ..., -0.01881691,
#         -0.01984685,  0.710484  ],
#        [ 0.0390744 ,  0.52384417, -0.0533881 , ..., -0.01881691,
#         -0.01984685, -0.05783643],
#        ...,
#        [ 0.03925374, -0.78824863, -0.0533881 , ..., -0.01881691,
#         -0.01984685, -0.2635719 ],
#        [ 0.0390744 , -0.24797512, -0.01623057, ..., -0.01881691,
#         -0.01984685, -0.27855225],
#        [ 0.0390744 ,  1.68157312, -0.0533881 , ..., -0.01881691,
#         -0.01984685, -0.22597242]])

# %%
x_test_filtered
# Out:
# array([[ 3.90744048e-02, -9.36112639e-02, -5.33881045e-02, ...,
#         -1.88169080e-02, -1.98468529e-02, -4.19918334e-01],
#        [ 3.90744048e-02,  1.37934525e-01, -5.33881045e-02, ...,
#         -1.88169080e-02, -1.98468529e-02, -3.92794017e-01],
#        [ 3.90744048e-02, -7.88248631e-01, -5.33881045e-02, ...,
#         -1.88169080e-02, -1.98468529e-02, -3.84542610e-01],
#        ...,
#        [ 3.90744048e-02, -7.11066701e-01, -5.33881045e-02, ...,
#         -1.88169080e-02, -1.98468529e-02,  2.74077683e-01],
#        [ 3.90744048e-02,  5.23844174e-01, -5.33881045e-02, ...,
#         -1.88169080e-02, -1.98468529e-02,  4.11519699e-04],
#        [ 3.90744048e-02, -7.88248631e-01, -5.33881045e-02, ...,
#         -1.88169080e-02, -1.98468529e-02,  4.11519699e-04]])

# %%
x_train.shape, x_val.shape, y_train.shape, y_val.shape
# Out:
# ((60816, 335), (15204, 335), (60816,), (15204,))

# %% [markdown]
# ### 2. model selection

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import GridSearchCV
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

# %%
xgb_clf = XGBClassifier(n_estimator=500, random=156)
xgb_clf.fit(x_train, y_train, early_stopping_rounds=100, eval_metric="auc",
            eval_set=[(x_train, y_train), (x_val, y_val)])
xgb_roc_score = roc_auc_score(y_val, xgb_clf.predict_proba(x_val)[:,1], average='macro')
print('ROC AUC : {0:.4f}'.format(xgb_roc_score))
# Out:
# c:\Users\HSMOON\anaconda3\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [00:08:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { n_estimator, random } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation_0-auc:0.82005	validation_1-auc:0.81163
# [1]	validation_0-auc:0.83400	validation_1-auc:0.82457
# [2]	validation_0-auc:0.83870	validation_1-auc:0.82748
# [3]	validation_0-auc:0.84419	validation_1-auc:0.82926
# [4]	validation_0-auc:0.84786	validation_1-auc:0.83301
# [5]	validation_0-auc:0.85150	validation_1-auc:0.83458
# [6]	validation_0-auc:0.85468	validation_1-auc:0.83603
# [7]	validation_0-auc:0.85832	validation_1-auc:0.83774
# [8]	validation_0-auc:0.86124	validation_1-auc:0.83916
# [9]	validation_0-auc:0.86461	validation_1-auc:0.84072
# [10]	validation_0-auc:0.86733	validation_1-auc:0.84160
# [11]	validation_0-auc:0.86992	validation_1-auc:0.84220
# [12]	validation_0-auc:0.87259	validation_1-auc:0.84196
# [13]	validation_0-auc:0.87587	validation_1-auc:0.84157
# [14]	validation_0-auc:0.87884	validation_1-auc:0.84317
# [15]	validation_0-auc:0.88130	validation_1-auc:0.84275
# [16]	validation_0-auc:0.88272	validation_1-auc:0.84204
# [17]	validation_0-auc:0.88409	validation_1-auc:0.84265
# [18]	validation_0-auc:0.88595	validation_1-auc:0.84242
# [19]	validation_0-auc:0.88698	validation_1-auc:0.84286
# [20]	validation_0-auc:0.88933	validation_1-auc:0.84221
# [21]	validation_0-auc:0.88988	validation_1-auc:0.84204
# [22]	validation_0-auc:0.89100	validation_1-auc:0.84213
# [23]	validation_0-auc:0.89145	validation_1-auc:0.84247
# [24]	validation_0-auc:0.89185	validation_1-auc:0.84253
# [25]	validation_0-auc:0.89236	validation_1-auc:0.84233
# [26]	validation_0-auc:0.89492	validation_1-auc:0.84167
# [27]	validation_0-auc:0.89514	validation_1-auc:0.84160
# [28]	validation_0-auc:0.89529	validation_1-auc:0.84161
# [29]	validation_0-auc:0.89559	validation_1-auc:0.84190
# [30]	validation_0-auc:0.89763	validation_1-auc:0.84088
# [31]	validation_0-auc:0.89851	validation_1-auc:0.84109
# [32]	validation_0-auc:0.89864	validation_1-auc:0.84113
# [33]	validation_0-auc:0.89908	validation_1-auc:0.84121
# [34]	validation_0-auc:0.89938	validation_1-auc:0.84101
# [35]	validation_0-auc:0.89962	validation_1-auc:0.84135
# [36]	validation_0-auc:0.90017	validation_1-auc:0.84105
# [37]	validation_0-auc:0.90035	validation_1-auc:0.84092
# [38]	validation_0-auc:0.90094	validation_1-auc:0.84119
# [39]	validation_0-auc:0.90199	validation_1-auc:0.84072
# [40]	validation_0-auc:0.90213	validation_1-auc:0.84039
# [41]	validation_0-auc:0.90301	validation_1-auc:0.83980
# [42]	validation_0-auc:0.90315	validation_1-auc:0.83969
# [43]	validation_0-auc:0.90455	validation_1-auc:0.83927
# [44]	validation_0-auc:0.90468	validation_1-auc:0.83930
# [45]	validation_0-auc:0.90564	validation_1-auc:0.83849
# [46]	validation_0-auc:0.90586	validation_1-auc:0.83853
# [47]	validation_0-auc:0.90732	validation_1-auc:0.83847
# [48]	validation_0-auc:0.91002	validation_1-auc:0.83824
# [49]	validation_0-auc:0.91022	validation_1-auc:0.83808
# [50]	validation_0-auc:0.91053	validation_1-auc:0.83761
# [51]	validation_0-auc:0.91196	validation_1-auc:0.83738
# [52]	validation_0-auc:0.91249	validation_1-auc:0.83714
# [53]	validation_0-auc:0.91306	validation_1-auc:0.83703
# [54]	validation_0-auc:0.91349	validation_1-auc:0.83708
# [55]	validation_0-auc:0.91407	validation_1-auc:0.83703
# [56]	validation_0-auc:0.91417	validation_1-auc:0.83701
# [57]	validation_0-auc:0.91436	validation_1-auc:0.83695
# [58]	validation_0-auc:0.91468	validation_1-auc:0.83672
# [59]	validation_0-auc:0.91474	validation_1-auc:0.83674
# [60]	validation_0-auc:0.91556	validation_1-auc:0.83655
# [61]	validation_0-auc:0.91647	validation_1-auc:0.83692
# [62]	validation_0-auc:0.91688	validation_1-auc:0.83659
# [63]	validation_0-auc:0.91700	validation_1-auc:0.83664
# [64]	validation_0-auc:0.91794	validation_1-auc:0.83713
# [65]	validation_0-auc:0.91806	validation_1-auc:0.83706
# [66]	validation_0-auc:0.91825	validation_1-auc:0.83691
# [67]	validation_0-auc:0.91857	validation_1-auc:0.83666
# [68]	validation_0-auc:0.91981	validation_1-auc:0.83554
# [69]	validation_0-auc:0.91988	validation_1-auc:0.83558
# [70]	validation_0-auc:0.91999	validation_1-auc:0.83553
# [71]	validation_0-auc:0.92022	validation_1-auc:0.83542
# [72]	validation_0-auc:0.92027	validation_1-auc:0.83526
# [73]	validation_0-auc:0.92036	validation_1-auc:0.83537
# [74]	validation_0-auc:0.92044	validation_1-auc:0.83544
# [75]	validation_0-auc:0.92087	validation_1-auc:0.83486
# [76]	validation_0-auc:0.92115	validation_1-auc:0.83436
# [77]	validation_0-auc:0.92207	validation_1-auc:0.83384
# [78]	validation_0-auc:0.92271	validation_1-auc:0.83377
# [79]	validation_0-auc:0.92322	validation_1-auc:0.83390
# [80]	validation_0-auc:0.92352	validation_1-auc:0.83381
# [81]	validation_0-auc:0.92421	validation_1-auc:0.83293
# [82]	validation_0-auc:0.92426	validation_1-auc:0.83292
# [83]	validation_0-auc:0.92512	validation_1-auc:0.83313
# [84]	validation_0-auc:0.92535	validation_1-auc:0.83293
# [85]	validation_0-auc:0.92664	validation_1-auc:0.83256
# [86]	validation_0-auc:0.92746	validation_1-auc:0.83285
# [87]	validation_0-auc:0.92801	validation_1-auc:0.83301
# [88]	validation_0-auc:0.92892	validation_1-auc:0.83265
# [89]	validation_0-auc:0.92899	validation_1-auc:0.83264
# [90]	validation_0-auc:0.92919	validation_1-auc:0.83247
# [91]	validation_0-auc:0.92939	validation_1-auc:0.83231
# [92]	validation_0-auc:0.92967	validation_1-auc:0.83243
# [93]	validation_0-auc:0.92977	validation_1-auc:0.83235
# [94]	validation_0-auc:0.92980	validation_1-auc:0.83223
# [95]	validation_0-auc:0.93024	validation_1-auc:0.83156
# [96]	validation_0-auc:0.93028	validation_1-auc:0.83161
# [97]	validation_0-auc:0.93035	validation_1-auc:0.83143
# [98]	validation_0-auc:0.93077	validation_1-auc:0.83130
# [99]	validation_0-auc:0.93123	validation_1-auc:0.83121
# ROC AUC : 0.8432

# %%
xgb_clf = XGBClassifier(n_estimator=100)

params = {
    'max_depth':[5,7],
    'min_child_weight':[1,3],
    'colsample_bytree':[0.5,0.75]    
}

gridcv = GridSearchCV(xgb_clf, param_grid=params, cv=3)
gridcv.fit(x_train,y_train,early_stopping_rounds=30,eval_metric='auc',
           eval_set = [(x_train,y_train),(x_val,y_val)])

print('GridSearchCV 최적 파라미터:', gridcv.best_params_)

xgb_roc_score = roc_auc_score(y_val, gridcv.predict_proba(x_val)[:,1], average='macro')
print('ROC AUC:{0:.4f}'.format(xgb_roc_score))
# Out:
# c:\Users\HSMOON\anaconda3\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [00:18:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { n_estimator } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation_0-auc:0.78989	validation_1-auc:0.79219
# [1]	validation_0-auc:0.80714	validation_1-auc:0.80666
# [2]	validation_0-auc:0.81198	validation_1-auc:0.81108
# [3]	validation_0-auc:0.82276	validation_1-auc:0.81989
# [4]	validation_0-auc:0.83185	validation_1-auc:0.82720
# [5]	validation_0-auc:0.82907	validation_1-auc:0.82635
# [6]	validation_0-auc:0.82607	validation_1-auc:0.82329
# [7]	validation_0-auc:0.83772	validation_1-auc:0.83166
# [8]	validation_0-auc:0.84285	validation_1-auc:0.83513
# [9]	validation_0-auc:0.84381	validation_1-auc:0.83542
# [10]	validation_0-auc:0.84849	validation_1-auc:0.83799
# [11]	validation_0-auc:0.84848	validation_1-auc:0.83663
# [12]	validation_0-auc:0.85258	validation_1-auc:0.83934
# [13]	validation_0-auc:0.85513	validation_1-auc:0.84141
# [14]	validation_0-auc:0.85589	validation_1-auc:0.84083
# [15]	validation_0-auc:0.85738	validation_1-auc:0.84123
# [16]	validation_0-auc:0.85905	validation_1-auc:0.84130
# [17]	validation_0-auc:0.86062	validation_1-auc:0.84030
# [18]	validation_0-auc:0.86167	validation_1-auc:0.83908
# [19]	validation_0-auc:0.86269	validation_1-auc:0.83873
# [20]	validation_0-auc:0.86301	validation_1-auc:0.83878
# [21]	validation_0-auc:0.86327	validation_1-auc:0.83837
# [22]	validation_0-auc:0.86410	validation_1-auc:0.83776
# [23]	validation_0-auc:0.86561	validation_1-auc:0.83802
# [24]	validation_0-auc:0.86625	validation_1-auc:0.83784
# [25]	validation_0-auc:0.86685	validation_1-auc:0.83833
# [26]	validation_0-auc:0.86728	validation_1-auc:0.83840
# [27]	validation_0-auc:0.86775	validation_1-auc:0.83796
# [28]	validation_0-auc:0.86794	validation_1-auc:0.83779
# [29]	validation_0-auc:0.86846	validation_1-auc:0.83698
# [30]	validation_0-auc:0.86914	validation_1-auc:0.83653
# [31]	validation_0-auc:0.86935	validation_1-auc:0.83680
# [32]	validation_0-auc:0.86941	validation_1-auc:0.83620
# [33]	validation_0-auc:0.86962	validation_1-auc:0.83609
# [34]	validation_0-auc:0.86993	validation_1-auc:0.83594
# [35]	validation_0-auc:0.87013	validation_1-auc:0.83612
# [36]	validation_0-auc:0.87033	validation_1-auc:0.83619
# [37]	validation_0-auc:0.87092	validation_1-auc:0.83645
# [38]	validation_0-auc:0.87177	validation_1-auc:0.83636
# [39]	validation_0-auc:0.87199	validation_1-auc:0.83638
# [40]	validation_0-auc:0.87277	validation_1-auc:0.83539
# [41]	validation_0-auc:0.87311	validation_1-auc:0.83526
# [42]	validation_0-auc:0.87421	validation_1-auc:0.83474
# [00:18:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { n_estimator } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation_0-auc:0.80180	validation_1-auc:0.79659
# [1]	validation_0-auc:0.81963	validation_1-auc:0.81540
# [2]	validation_0-auc:0.82658	validation_1-auc:0.82617
# [3]	validation_0-auc:0.82974	validation_1-auc:0.82627
# [4]	validation_0-auc:0.83698	validation_1-auc:0.83039
# [5]	validation_0-auc:0.83690	validation_1-auc:0.83246
# [6]	validation_0-auc:0.83287	validation_1-auc:0.82721
# [7]	validation_0-auc:0.84324	validation_1-auc:0.83448
# [8]	validation_0-auc:0.84752	validation_1-auc:0.83688
# [9]	validation_0-auc:0.84698	validation_1-auc:0.83570
# [10]	validation_0-auc:0.85223	validation_1-auc:0.84022
# [11]	validation_0-auc:0.85149	validation_1-auc:0.83884
# [12]	validation_0-auc:0.85520	validation_1-auc:0.84093
# [13]	validation_0-auc:0.85746	validation_1-auc:0.84182
# [14]	validation_0-auc:0.85881	validation_1-auc:0.84366
# [15]	validation_0-auc:0.86016	validation_1-auc:0.84376
# [16]	validation_0-auc:0.86175	validation_1-auc:0.84304
# [17]	validation_0-auc:0.86240	validation_1-auc:0.84277
# [18]	validation_0-auc:0.86341	validation_1-auc:0.84271
# [19]	validation_0-auc:0.86453	validation_1-auc:0.84226
# [20]	validation_0-auc:0.86483	validation_1-auc:0.84281
# [21]	validation_0-auc:0.86523	validation_1-auc:0.84294
# [22]	validation_0-auc:0.86622	validation_1-auc:0.84282
# [23]	validation_0-auc:0.86703	validation_1-auc:0.84254
# [24]	validation_0-auc:0.86772	validation_1-auc:0.84258
# [25]	validation_0-auc:0.86814	validation_1-auc:0.84271
# [26]	validation_0-auc:0.86841	validation_1-auc:0.84289
# [27]	validation_0-auc:0.86960	validation_1-auc:0.84293
# [28]	validation_0-auc:0.87023	validation_1-auc:0.84293
# [29]	validation_0-auc:0.87082	validation_1-auc:0.84272
# [30]	validation_0-auc:0.87166	validation_1-auc:0.84267
# [31]	validation_0-auc:0.87180	validation_1-auc:0.84266
# [32]	validation_0-auc:0.87203	validation_1-auc:0.84286
# [33]	validation_0-auc:0.87207	validation_1-auc:0.84296
# [34]	validation_0-auc:0.87237	validation_1-auc:0.84247
# [35]	validation_0-auc:0.87366	validation_1-auc:0.84290
# [36]	validation_0-auc:0.87392	validation_1-auc:0.84290
# [37]	validation_0-auc:0.87440	validation_1-auc:0.84277
# [38]	validation_0-auc:0.87461	validation_1-auc:0.84232
# [39]	validation_0-auc:0.87513	validation_1-auc:0.84190
# [40]	validation_0-auc:0.87527	validation_1-auc:0.84191
# [41]	validation_0-auc:0.87554	validation_1-auc:0.84169
# [42]	validation_0-auc:0.87589	validation_1-auc:0.84109
# [43]	validation_0-auc:0.87664	validation_1-auc:0.84111
# [44]	validation_0-auc:0.87666	validation_1-auc:0.84146
# [45]	validation_0-auc:0.87689	validation_1-auc:0.84131
# [00:18:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { n_estimator } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation_0-auc:0.79053	validation_1-auc:0.78918
# [1]	validation_0-auc:0.82256	validation_1-auc:0.82301
# [2]	validation_0-auc:0.82578	validation_1-auc:0.82845
# [3]	validation_0-auc:0.83329	validation_1-auc:0.83412
# [4]	validation_0-auc:0.83775	validation_1-auc:0.83486
# [5]	validation_0-auc:0.83646	validation_1-auc:0.83477
# [6]	validation_0-auc:0.83284	validation_1-auc:0.82731
# [7]	validation_0-auc:0.84164	validation_1-auc:0.83340
# [8]	validation_0-auc:0.84759	validation_1-auc:0.83628
# [9]	validation_0-auc:0.84739	validation_1-auc:0.83515
# [10]	validation_0-auc:0.85113	validation_1-auc:0.83754
# [11]	validation_0-auc:0.85083	validation_1-auc:0.83571
# [12]	validation_0-auc:0.85461	validation_1-auc:0.83768
# [13]	validation_0-auc:0.85626	validation_1-auc:0.83860
# [14]	validation_0-auc:0.85786	validation_1-auc:0.84062
# [15]	validation_0-auc:0.85918	validation_1-auc:0.84001
# [16]	validation_0-auc:0.86122	validation_1-auc:0.84074
# [17]	validation_0-auc:0.86230	validation_1-auc:0.84073
# [18]	validation_0-auc:0.86289	validation_1-auc:0.84032
# [19]	validation_0-auc:0.86380	validation_1-auc:0.84102
# [20]	validation_0-auc:0.86406	validation_1-auc:0.84109
# [21]	validation_0-auc:0.86497	validation_1-auc:0.84060
# [22]	validation_0-auc:0.86650	validation_1-auc:0.84101
# [23]	validation_0-auc:0.86735	validation_1-auc:0.84098
# [24]	validation_0-auc:0.86879	validation_1-auc:0.84034
# [25]	validation_0-auc:0.87021	validation_1-auc:0.84044
# [26]	validation_0-auc:0.87049	validation_1-auc:0.84032
# [27]	validation_0-auc:0.87090	validation_1-auc:0.84009
# [28]	validation_0-auc:0.87113	validation_1-auc:0.83996
# [29]	validation_0-auc:0.87185	validation_1-auc:0.84082
# [30]	validation_0-auc:0.87264	validation_1-auc:0.84020
# [31]	validation_0-auc:0.87297	validation_1-auc:0.83992
# [32]	validation_0-auc:0.87328	validation_1-auc:0.84020
# [33]	validation_0-auc:0.87375	validation_1-auc:0.84004
# [34]	validation_0-auc:0.87450	validation_1-auc:0.83958
# [35]	validation_0-auc:0.87485	validation_1-auc:0.83961
# [36]	validation_0-auc:0.87506	validation_1-auc:0.83948
# [37]	validation_0-auc:0.87525	validation_1-auc:0.83933
# [38]	validation_0-auc:0.87597	validation_1-auc:0.83885
# [39]	validation_0-auc:0.87616	validation_1-auc:0.83854
# [40]	validation_0-auc:0.87649	validation_1-auc:0.83828
# [41]	validation_0-auc:0.87683	validation_1-auc:0.83803
# [42]	validation_0-auc:0.87692	validation_1-auc:0.83781
# [43]	validation_0-auc:0.87756	validation_1-auc:0.83750
# [44]	validation_0-auc:0.87818	validation_1-auc:0.83710
# [45]	validation_0-auc:0.87845	validation_1-auc:0.83690
# [46]	validation_0-auc:0.87858	validation_1-auc:0.83676
# [47]	validation_0-auc:0.87962	validation_1-auc:0.83645
# [48]	validation_0-auc:0.87978	validation_1-auc:0.83640
# [49]	validation_0-auc:0.88021	validation_1-auc:0.83689
# [50]	validation_0-auc:0.88037	validation_1-auc:0.83699
# [00:18:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { n_estimator } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation_0-auc:0.78957	validation_1-auc:0.79289
# [1]	validation_0-auc:0.80684	validation_1-auc:0.80639
# [2]	validation_0-auc:0.81134	validation_1-auc:0.81383
# [3]	validation_0-auc:0.82176	validation_1-auc:0.82081
# [4]	validation_0-auc:0.83307	validation_1-auc:0.82857
# [5]	validation_0-auc:0.82963	validation_1-auc:0.82698
# [6]	validation_0-auc:0.82675	validation_1-auc:0.82434
# [7]	validation_0-auc:0.83753	validation_1-auc:0.83307
# [8]	validation_0-auc:0.84297	validation_1-auc:0.83671
# [9]	validation_0-auc:0.84368	validation_1-auc:0.83559
# [10]	validation_0-auc:0.84919	validation_1-auc:0.83909
# [11]	validation_0-auc:0.84820	validation_1-auc:0.83759
# [12]	validation_0-auc:0.85162	validation_1-auc:0.84069
# [13]	validation_0-auc:0.85309	validation_1-auc:0.84102
# [14]	validation_0-auc:0.85407	validation_1-auc:0.83936
# [15]	validation_0-auc:0.85547	validation_1-auc:0.84072
# [16]	validation_0-auc:0.85749	validation_1-auc:0.83997
# [17]	validation_0-auc:0.85824	validation_1-auc:0.83926
# [18]	validation_0-auc:0.85912	validation_1-auc:0.83749
# [19]	validation_0-auc:0.86005	validation_1-auc:0.83759
# [20]	validation_0-auc:0.86115	validation_1-auc:0.83761
# [21]	validation_0-auc:0.86140	validation_1-auc:0.83751
# [22]	validation_0-auc:0.86221	validation_1-auc:0.83749
# [23]	validation_0-auc:0.86281	validation_1-auc:0.83736
# [24]	validation_0-auc:0.86342	validation_1-auc:0.83710
# [25]	validation_0-auc:0.86381	validation_1-auc:0.83732
# [26]	validation_0-auc:0.86435	validation_1-auc:0.83731
# [27]	validation_0-auc:0.86482	validation_1-auc:0.83748
# [28]	validation_0-auc:0.86500	validation_1-auc:0.83758
# [29]	validation_0-auc:0.86567	validation_1-auc:0.83716
# [30]	validation_0-auc:0.86644	validation_1-auc:0.83751
# [31]	validation_0-auc:0.86699	validation_1-auc:0.83674
# [32]	validation_0-auc:0.86705	validation_1-auc:0.83666
# [33]	validation_0-auc:0.86728	validation_1-auc:0.83684
# [34]	validation_0-auc:0.86805	validation_1-auc:0.83600
# [35]	validation_0-auc:0.86813	validation_1-auc:0.83603
# [36]	validation_0-auc:0.86828	validation_1-auc:0.83608
# [37]	validation_0-auc:0.86837	validation_1-auc:0.83620
# [38]	validation_0-auc:0.86920	validation_1-auc:0.83579
# [39]	validation_0-auc:0.86982	validation_1-auc:0.83579
# [40]	validation_0-auc:0.86986	validation_1-auc:0.83575
# [41]	validation_0-auc:0.86983	validation_1-auc:0.83559
# [42]	validation_0-auc:0.87023	validation_1-auc:0.83564
# [00:19:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { n_estimator } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation_0-auc:0.80475	validation_1-auc:0.79575
# [1]	validation_0-auc:0.81960	validation_1-auc:0.81609
# [2]	validation_0-auc:0.82543	validation_1-auc:0.82656
# [3]	validation_0-auc:0.83079	validation_1-auc:0.83063
# [4]	validation_0-auc:0.83474	validation_1-auc:0.83333
# [5]	validation_0-auc:0.83455	validation_1-auc:0.83357
# [6]	validation_0-auc:0.83080	validation_1-auc:0.82831
# [7]	validation_0-auc:0.84184	validation_1-auc:0.83492
# [8]	validation_0-auc:0.84663	validation_1-auc:0.83699
# [9]	validation_0-auc:0.84539	validation_1-auc:0.83503
# [10]	validation_0-auc:0.85097	validation_1-auc:0.83914
# [11]	validation_0-auc:0.84997	validation_1-auc:0.83731
# [12]	validation_0-auc:0.85363	validation_1-auc:0.84026
# [13]	validation_0-auc:0.85605	validation_1-auc:0.84098
# [14]	validation_0-auc:0.85700	validation_1-auc:0.84167
# [15]	validation_0-auc:0.85793	validation_1-auc:0.84171
# [16]	validation_0-auc:0.85917	validation_1-auc:0.84249
# [17]	validation_0-auc:0.85974	validation_1-auc:0.84240
# [18]	validation_0-auc:0.86085	validation_1-auc:0.84238
# [19]	validation_0-auc:0.86143	validation_1-auc:0.84205
# [20]	validation_0-auc:0.86246	validation_1-auc:0.84210
# [21]	validation_0-auc:0.86286	validation_1-auc:0.84198
# [22]	validation_0-auc:0.86394	validation_1-auc:0.84183
# [23]	validation_0-auc:0.86488	validation_1-auc:0.84228
# [24]	validation_0-auc:0.86528	validation_1-auc:0.84213
# [25]	validation_0-auc:0.86540	validation_1-auc:0.84225
# [26]	validation_0-auc:0.86581	validation_1-auc:0.84223
# [27]	validation_0-auc:0.86607	validation_1-auc:0.84173
# [28]	validation_0-auc:0.86611	validation_1-auc:0.84181
# [29]	validation_0-auc:0.86655	validation_1-auc:0.84174
# [30]	validation_0-auc:0.86728	validation_1-auc:0.84201
# [31]	validation_0-auc:0.86779	validation_1-auc:0.84202
# [32]	validation_0-auc:0.86905	validation_1-auc:0.84135
# [33]	validation_0-auc:0.86920	validation_1-auc:0.84149
# [34]	validation_0-auc:0.86932	validation_1-auc:0.84154
# [35]	validation_0-auc:0.87023	validation_1-auc:0.84175
# [36]	validation_0-auc:0.87068	validation_1-auc:0.84173
# [37]	validation_0-auc:0.87143	validation_1-auc:0.84108
# [38]	validation_0-auc:0.87159	validation_1-auc:0.84096
# [39]	validation_0-auc:0.87164	validation_1-auc:0.84128
# [40]	validation_0-auc:0.87186	validation_1-auc:0.84145
# [41]	validation_0-auc:0.87206	validation_1-auc:0.84095
# [42]	validation_0-auc:0.87222	validation_1-auc:0.84102
# [43]	validation_0-auc:0.87240	validation_1-auc:0.84092
# [44]	validation_0-auc:0.87273	validation_1-auc:0.84064
# [45]	validation_0-auc:0.87300	validation_1-auc:0.84055
# [46]	validation_0-auc:0.87349	validation_1-auc:0.83986
# [00:19:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { n_estimator } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation_0-auc:0.80766	validation_1-auc:0.81112
# [1]	validation_0-auc:0.82310	validation_1-auc:0.82144
# [2]	validation_0-auc:0.82613	validation_1-auc:0.82689
# [3]	validation_0-auc:0.83387	validation_1-auc:0.83457
# [4]	validation_0-auc:0.83817	validation_1-auc:0.83726
# [5]	validation_0-auc:0.83741	validation_1-auc:0.83514
# [6]	validation_0-auc:0.83371	validation_1-auc:0.82805
# [7]	validation_0-auc:0.84257	validation_1-auc:0.83400
# [8]	validation_0-auc:0.84667	validation_1-auc:0.83651
# [9]	validation_0-auc:0.84626	validation_1-auc:0.83491
# [10]	validation_0-auc:0.85038	validation_1-auc:0.83796
# [11]	validation_0-auc:0.84994	validation_1-auc:0.83627
# [12]	validation_0-auc:0.85320	validation_1-auc:0.83826
# [13]	validation_0-auc:0.85469	validation_1-auc:0.83860
# [14]	validation_0-auc:0.85570	validation_1-auc:0.83866
# [15]	validation_0-auc:0.85649	validation_1-auc:0.83950
# [16]	validation_0-auc:0.85785	validation_1-auc:0.84105
# [17]	validation_0-auc:0.85851	validation_1-auc:0.84095
# [18]	validation_0-auc:0.85914	validation_1-auc:0.84044
# [19]	validation_0-auc:0.86010	validation_1-auc:0.84016
# [20]	validation_0-auc:0.86053	validation_1-auc:0.84062
# [21]	validation_0-auc:0.86105	validation_1-auc:0.84032
# [22]	validation_0-auc:0.86206	validation_1-auc:0.84135
# [23]	validation_0-auc:0.86306	validation_1-auc:0.84083
# [24]	validation_0-auc:0.86367	validation_1-auc:0.84129
# [25]	validation_0-auc:0.86490	validation_1-auc:0.84149
# [26]	validation_0-auc:0.86497	validation_1-auc:0.84152
# [27]	validation_0-auc:0.86510	validation_1-auc:0.84169
# [28]	validation_0-auc:0.86584	validation_1-auc:0.84118
# [29]	validation_0-auc:0.86620	validation_1-auc:0.84122
# [30]	validation_0-auc:0.86655	validation_1-auc:0.84115
# [31]	validation_0-auc:0.86684	validation_1-auc:0.84079
# [32]	validation_0-auc:0.86792	validation_1-auc:0.84017
# [33]	validation_0-auc:0.86788	validation_1-auc:0.84014
# [34]	validation_0-auc:0.86803	validation_1-auc:0.84003
# [35]	validation_0-auc:0.86838	validation_1-auc:0.84005
# [36]	validation_0-auc:0.86907	validation_1-auc:0.84022
# [37]	validation_0-auc:0.86955	validation_1-auc:0.84007
# [38]	validation_0-auc:0.86977	validation_1-auc:0.84029
# [39]	validation_0-auc:0.87068	validation_1-auc:0.83939
# [40]	validation_0-auc:0.87080	validation_1-auc:0.83939
# [41]	validation_0-auc:0.87140	validation_1-auc:0.83903
# [42]	validation_0-auc:0.87192	validation_1-auc:0.83881
# [43]	validation_0-auc:0.87316	validation_1-auc:0.83858
# [44]	validation_0-auc:0.87337	validation_1-auc:0.83831
# [45]	validation_0-auc:0.87377	validation_1-auc:0.83832
# [46]	validation_0-auc:0.87389	validation_1-auc:0.83819
# [47]	validation_0-auc:0.87420	validation_1-auc:0.83724
# [48]	validation_0-auc:0.87435	validation_1-auc:0.83704
# [49]	validation_0-auc:0.87462	validation_1-auc:0.83677
# [50]	validation_0-auc:0.87492	validation_1-auc:0.83660
# [51]	validation_0-auc:0.87514	validation_1-auc:0.83644
# [52]	validation_0-auc:0.87538	validation_1-auc:0.83608
# [53]	validation_0-auc:0.87553	validation_1-auc:0.83614
# [54]	validation_0-auc:0.87591	validation_1-auc:0.83606
# [55]	validation_0-auc:0.87597	validation_1-auc:0.83613
# [56]	validation_0-auc:0.87634	validation_1-auc:0.83574
# [00:19:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { n_estimator } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation_0-auc:0.80037	validation_1-auc:0.80614
# [1]	validation_0-auc:0.82158	validation_1-auc:0.82097
# [2]	validation_0-auc:0.82735	validation_1-auc:0.82282
# [3]	validation_0-auc:0.83973	validation_1-auc:0.83120
# [4]	validation_0-auc:0.84476	validation_1-auc:0.83340
# [5]	validation_0-auc:0.84516	validation_1-auc:0.82964
# [6]	validation_0-auc:0.84329	validation_1-auc:0.82468
# [7]	validation_0-auc:0.85244	validation_1-auc:0.83174
# [8]	validation_0-auc:0.85969	validation_1-auc:0.83613
# [9]	validation_0-auc:0.86068	validation_1-auc:0.83066
# [10]	validation_0-auc:0.86613	validation_1-auc:0.83332
# [11]	validation_0-auc:0.86676	validation_1-auc:0.82983
# [12]	validation_0-auc:0.87130	validation_1-auc:0.83355
# [13]	validation_0-auc:0.87412	validation_1-auc:0.83329
# [14]	validation_0-auc:0.87603	validation_1-auc:0.83296
# [15]	validation_0-auc:0.87732	validation_1-auc:0.83371
# [16]	validation_0-auc:0.87923	validation_1-auc:0.83293
# [17]	validation_0-auc:0.88040	validation_1-auc:0.83296
# [18]	validation_0-auc:0.88110	validation_1-auc:0.83171
# [19]	validation_0-auc:0.88196	validation_1-auc:0.83228
# [20]	validation_0-auc:0.88209	validation_1-auc:0.83277
# [21]	validation_0-auc:0.88250	validation_1-auc:0.83236
# [22]	validation_0-auc:0.88258	validation_1-auc:0.83219
# [23]	validation_0-auc:0.88303	validation_1-auc:0.83180
# [24]	validation_0-auc:0.88437	validation_1-auc:0.83175
# [25]	validation_0-auc:0.88482	validation_1-auc:0.83157
# [26]	validation_0-auc:0.88499	validation_1-auc:0.83151
# [27]	validation_0-auc:0.88622	validation_1-auc:0.83200
# [28]	validation_0-auc:0.88629	validation_1-auc:0.83237
# [29]	validation_0-auc:0.88657	validation_1-auc:0.83283
# [30]	validation_0-auc:0.88783	validation_1-auc:0.83210
# [31]	validation_0-auc:0.88840	validation_1-auc:0.83063
# [32]	validation_0-auc:0.88839	validation_1-auc:0.83047
# [33]	validation_0-auc:0.88865	validation_1-auc:0.82977
# [34]	validation_0-auc:0.88857	validation_1-auc:0.82969
# [35]	validation_0-auc:0.88856	validation_1-auc:0.82949
# [36]	validation_0-auc:0.88931	validation_1-auc:0.82943
# [37]	validation_0-auc:0.88981	validation_1-auc:0.82883
# [00:19:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { n_estimator } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation_0-auc:0.80889	validation_1-auc:0.80069
# [1]	validation_0-auc:0.82761	validation_1-auc:0.82044
# [2]	validation_0-auc:0.83370	validation_1-auc:0.82816
# [3]	validation_0-auc:0.84315	validation_1-auc:0.83599
# [4]	validation_0-auc:0.84856	validation_1-auc:0.83637
# [5]	validation_0-auc:0.84977	validation_1-auc:0.83576
# [6]	validation_0-auc:0.85016	validation_1-auc:0.83137
# [7]	validation_0-auc:0.85725	validation_1-auc:0.83531
# [8]	validation_0-auc:0.86336	validation_1-auc:0.83862
# [9]	validation_0-auc:0.86268	validation_1-auc:0.83624
# [10]	validation_0-auc:0.86829	validation_1-auc:0.83913
# [11]	validation_0-auc:0.86891	validation_1-auc:0.83778
# [12]	validation_0-auc:0.87372	validation_1-auc:0.84037
# [13]	validation_0-auc:0.87690	validation_1-auc:0.83969
# [14]	validation_0-auc:0.87895	validation_1-auc:0.84200
# [15]	validation_0-auc:0.88036	validation_1-auc:0.84157
# [16]	validation_0-auc:0.88158	validation_1-auc:0.84308
# [17]	validation_0-auc:0.88338	validation_1-auc:0.84354
# [18]	validation_0-auc:0.88495	validation_1-auc:0.84285
# [19]	validation_0-auc:0.88596	validation_1-auc:0.84247
# [20]	validation_0-auc:0.88656	validation_1-auc:0.84250
# [21]	validation_0-auc:0.88746	validation_1-auc:0.84183
# [22]	validation_0-auc:0.88855	validation_1-auc:0.84180
# [23]	validation_0-auc:0.88929	validation_1-auc:0.84144
# [24]	validation_0-auc:0.88962	validation_1-auc:0.84172
# [25]	validation_0-auc:0.88998	validation_1-auc:0.84156
# [26]	validation_0-auc:0.89018	validation_1-auc:0.84160
# [27]	validation_0-auc:0.89034	validation_1-auc:0.84071
# [28]	validation_0-auc:0.89056	validation_1-auc:0.84069
# [29]	validation_0-auc:0.89220	validation_1-auc:0.83994
# [30]	validation_0-auc:0.89296	validation_1-auc:0.83942
# [31]	validation_0-auc:0.89374	validation_1-auc:0.83955
# [32]	validation_0-auc:0.89379	validation_1-auc:0.83958
# [33]	validation_0-auc:0.89385	validation_1-auc:0.83866
# [34]	validation_0-auc:0.89397	validation_1-auc:0.83857
# [35]	validation_0-auc:0.89428	validation_1-auc:0.83722
# [36]	validation_0-auc:0.89455	validation_1-auc:0.83741
# [37]	validation_0-auc:0.89480	validation_1-auc:0.83738
# [38]	validation_0-auc:0.89525	validation_1-auc:0.83631
# [39]	validation_0-auc:0.89550	validation_1-auc:0.83580
# [40]	validation_0-auc:0.89554	validation_1-auc:0.83591
# [41]	validation_0-auc:0.89572	validation_1-auc:0.83639
# [42]	validation_0-auc:0.89644	validation_1-auc:0.83488
# [43]	validation_0-auc:0.89647	validation_1-auc:0.83527
# [44]	validation_0-auc:0.89699	validation_1-auc:0.83510
# [45]	validation_0-auc:0.89723	validation_1-auc:0.83523
# [46]	validation_0-auc:0.89730	validation_1-auc:0.83516
# [47]	validation_0-auc:0.89740	validation_1-auc:0.83499
# [00:19:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { n_estimator } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation_0-auc:0.80679	validation_1-auc:0.80150
# [1]	validation_0-auc:0.83070	validation_1-auc:0.82877
# [2]	validation_0-auc:0.83374	validation_1-auc:0.83064
# [3]	validation_0-auc:0.84388	validation_1-auc:0.83611
# [4]	validation_0-auc:0.85029	validation_1-auc:0.83743
# [5]	validation_0-auc:0.84813	validation_1-auc:0.83278
# [6]	validation_0-auc:0.84761	validation_1-auc:0.82863
# [7]	validation_0-auc:0.85580	validation_1-auc:0.83491
# [8]	validation_0-auc:0.86019	validation_1-auc:0.83684
# [9]	validation_0-auc:0.86145	validation_1-auc:0.83580
# [10]	validation_0-auc:0.86813	validation_1-auc:0.83930
# [11]	validation_0-auc:0.86781	validation_1-auc:0.83715
# [12]	validation_0-auc:0.87226	validation_1-auc:0.83898
# [13]	validation_0-auc:0.87436	validation_1-auc:0.83995
# [14]	validation_0-auc:0.87647	validation_1-auc:0.83977
# [15]	validation_0-auc:0.87781	validation_1-auc:0.83981
# [16]	validation_0-auc:0.88040	validation_1-auc:0.83957
# [17]	validation_0-auc:0.88182	validation_1-auc:0.83911
# [18]	validation_0-auc:0.88261	validation_1-auc:0.83892
# [19]	validation_0-auc:0.88396	validation_1-auc:0.83939
# [20]	validation_0-auc:0.88418	validation_1-auc:0.83904
# [21]	validation_0-auc:0.88466	validation_1-auc:0.83974
# [22]	validation_0-auc:0.88602	validation_1-auc:0.84035
# [23]	validation_0-auc:0.88718	validation_1-auc:0.83975
# [24]	validation_0-auc:0.88853	validation_1-auc:0.83937
# [25]	validation_0-auc:0.88900	validation_1-auc:0.83909
# [26]	validation_0-auc:0.88892	validation_1-auc:0.83907
# [27]	validation_0-auc:0.88917	validation_1-auc:0.83904
# [28]	validation_0-auc:0.88943	validation_1-auc:0.83811
# [29]	validation_0-auc:0.88956	validation_1-auc:0.83799
# [30]	validation_0-auc:0.89037	validation_1-auc:0.83732
# [31]	validation_0-auc:0.89085	validation_1-auc:0.83757
# [32]	validation_0-auc:0.89111	validation_1-auc:0.83721
# [33]	validation_0-auc:0.89184	validation_1-auc:0.83749
# [34]	validation_0-auc:0.89210	validation_1-auc:0.83700
# [35]	validation_0-auc:0.89278	validation_1-auc:0.83639
# [36]	validation_0-auc:0.89343	validation_1-auc:0.83616
# [37]	validation_0-auc:0.89371	validation_1-auc:0.83616
# [38]	validation_0-auc:0.89385	validation_1-auc:0.83633
# [39]	validation_0-auc:0.89396	validation_1-auc:0.83584
# [40]	validation_0-auc:0.89399	validation_1-auc:0.83583
# [41]	validation_0-auc:0.89438	validation_1-auc:0.83600
# [42]	validation_0-auc:0.89455	validation_1-auc:0.83564
# [43]	validation_0-auc:0.89468	validation_1-auc:0.83566
# [44]	validation_0-auc:0.89568	validation_1-auc:0.83594
# [45]	validation_0-auc:0.89574	validation_1-auc:0.83566
# [46]	validation_0-auc:0.89579	validation_1-auc:0.83524
# [47]	validation_0-auc:0.89592	validation_1-auc:0.83461
# [48]	validation_0-auc:0.89628	validation_1-auc:0.83419
# [49]	validation_0-auc:0.89629	validation_1-auc:0.83437
# [50]	validation_0-auc:0.89628	validation_1-auc:0.83440
# [51]	validation_0-auc:0.89630	validation_1-auc:0.83407
# [00:20:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { n_estimator } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation_0-auc:0.79938	validation_1-auc:0.80523
# [1]	validation_0-auc:0.81997	validation_1-auc:0.81916
# [2]	validation_0-auc:0.82594	validation_1-auc:0.81903
# [3]	validation_0-auc:0.83660	validation_1-auc:0.82763
# [4]	validation_0-auc:0.84227	validation_1-auc:0.83260
# [5]	validation_0-auc:0.84279	validation_1-auc:0.83083
# [6]	validation_0-auc:0.84094	validation_1-auc:0.82404
# [7]	validation_0-auc:0.84944	validation_1-auc:0.83090
# [8]	validation_0-auc:0.85576	validation_1-auc:0.83476
# [9]	validation_0-auc:0.85597	validation_1-auc:0.83211
# [10]	validation_0-auc:0.85979	validation_1-auc:0.83490
# [11]	validation_0-auc:0.85971	validation_1-auc:0.83216
# [12]	validation_0-auc:0.86412	validation_1-auc:0.83433
# [13]	validation_0-auc:0.86644	validation_1-auc:0.83611
# [14]	validation_0-auc:0.86866	validation_1-auc:0.83640
# [15]	validation_0-auc:0.86999	validation_1-auc:0.83718
# [16]	validation_0-auc:0.87077	validation_1-auc:0.83775
# [17]	validation_0-auc:0.87219	validation_1-auc:0.83669
# [18]	validation_0-auc:0.87319	validation_1-auc:0.83508
# [19]	validation_0-auc:0.87332	validation_1-auc:0.83439
# [20]	validation_0-auc:0.87348	validation_1-auc:0.83452
# [21]	validation_0-auc:0.87385	validation_1-auc:0.83440
# [22]	validation_0-auc:0.87486	validation_1-auc:0.83505
# [23]	validation_0-auc:0.87678	validation_1-auc:0.83586
# [24]	validation_0-auc:0.87713	validation_1-auc:0.83580
# [25]	validation_0-auc:0.87726	validation_1-auc:0.83591
# [26]	validation_0-auc:0.87734	validation_1-auc:0.83491
# [27]	validation_0-auc:0.87827	validation_1-auc:0.83463
# [28]	validation_0-auc:0.87843	validation_1-auc:0.83481
# [29]	validation_0-auc:0.87948	validation_1-auc:0.83407
# [30]	validation_0-auc:0.87964	validation_1-auc:0.83421
# [31]	validation_0-auc:0.88076	validation_1-auc:0.83437
# [32]	validation_0-auc:0.88235	validation_1-auc:0.83430
# [33]	validation_0-auc:0.88279	validation_1-auc:0.83282
# [34]	validation_0-auc:0.88343	validation_1-auc:0.83339
# [35]	validation_0-auc:0.88379	validation_1-auc:0.83243
# [36]	validation_0-auc:0.88421	validation_1-auc:0.83221
# [37]	validation_0-auc:0.88438	validation_1-auc:0.83214
# [38]	validation_0-auc:0.88507	validation_1-auc:0.83223
# [39]	validation_0-auc:0.88513	validation_1-auc:0.83180
# [40]	validation_0-auc:0.88524	validation_1-auc:0.83178
# [41]	validation_0-auc:0.88680	validation_1-auc:0.83082
# [42]	validation_0-auc:0.88728	validation_1-auc:0.83092
# [43]	validation_0-auc:0.88773	validation_1-auc:0.83151
# [44]	validation_0-auc:0.88753	validation_1-auc:0.83078
# [45]	validation_0-auc:0.88772	validation_1-auc:0.83087
# [46]	validation_0-auc:0.88794	validation_1-auc:0.83081
# [00:20:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { n_estimator } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation_0-auc:0.81097	validation_1-auc:0.79828
# [1]	validation_0-auc:0.82781	validation_1-auc:0.82053
# [2]	validation_0-auc:0.83175	validation_1-auc:0.82805
# [3]	validation_0-auc:0.84318	validation_1-auc:0.83415
# [4]	validation_0-auc:0.84728	validation_1-auc:0.83765
# [5]	validation_0-auc:0.84695	validation_1-auc:0.83436
# [6]	validation_0-auc:0.84785	validation_1-auc:0.83087
# [7]	validation_0-auc:0.85446	validation_1-auc:0.83454
# [8]	validation_0-auc:0.86035	validation_1-auc:0.83562
# [9]	validation_0-auc:0.85916	validation_1-auc:0.83654
# [10]	validation_0-auc:0.86375	validation_1-auc:0.83909
# [11]	validation_0-auc:0.86449	validation_1-auc:0.83753
# [12]	validation_0-auc:0.86860	validation_1-auc:0.84021
# [13]	validation_0-auc:0.87147	validation_1-auc:0.84178
# [14]	validation_0-auc:0.87322	validation_1-auc:0.84096
# [15]	validation_0-auc:0.87363	validation_1-auc:0.84055
# [16]	validation_0-auc:0.87588	validation_1-auc:0.84035
# [17]	validation_0-auc:0.87697	validation_1-auc:0.84168
# [18]	validation_0-auc:0.87782	validation_1-auc:0.84047
# [19]	validation_0-auc:0.87848	validation_1-auc:0.83939
# [20]	validation_0-auc:0.87902	validation_1-auc:0.83950
# [21]	validation_0-auc:0.87912	validation_1-auc:0.83983
# [22]	validation_0-auc:0.87986	validation_1-auc:0.83946
# [23]	validation_0-auc:0.88028	validation_1-auc:0.83885
# [24]	validation_0-auc:0.88120	validation_1-auc:0.83916
# [25]	validation_0-auc:0.88148	validation_1-auc:0.83849
# [26]	validation_0-auc:0.88158	validation_1-auc:0.83852
# [27]	validation_0-auc:0.88165	validation_1-auc:0.83841
# [28]	validation_0-auc:0.88193	validation_1-auc:0.83824
# [29]	validation_0-auc:0.88286	validation_1-auc:0.83766
# [30]	validation_0-auc:0.88342	validation_1-auc:0.83706
# [31]	validation_0-auc:0.88409	validation_1-auc:0.83685
# [32]	validation_0-auc:0.88483	validation_1-auc:0.83702
# [33]	validation_0-auc:0.88509	validation_1-auc:0.83698
# [34]	validation_0-auc:0.88521	validation_1-auc:0.83729
# [35]	validation_0-auc:0.88584	validation_1-auc:0.83698
# [36]	validation_0-auc:0.88627	validation_1-auc:0.83681
# [37]	validation_0-auc:0.88686	validation_1-auc:0.83674
# [38]	validation_0-auc:0.88726	validation_1-auc:0.83668
# [39]	validation_0-auc:0.88747	validation_1-auc:0.83655
# [40]	validation_0-auc:0.88782	validation_1-auc:0.83656
# [41]	validation_0-auc:0.88806	validation_1-auc:0.83662
# [42]	validation_0-auc:0.88837	validation_1-auc:0.83637
# [43]	validation_0-auc:0.88857	validation_1-auc:0.83564
# [00:20:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { n_estimator } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation_0-auc:0.81182	validation_1-auc:0.81065
# [1]	validation_0-auc:0.82888	validation_1-auc:0.82414
# [2]	validation_0-auc:0.83346	validation_1-auc:0.82774
# [3]	validation_0-auc:0.84269	validation_1-auc:0.83191
# [4]	validation_0-auc:0.84692	validation_1-auc:0.83487
# [5]	validation_0-auc:0.84591	validation_1-auc:0.83078
# [6]	validation_0-auc:0.84506	validation_1-auc:0.82672
# [7]	validation_0-auc:0.85111	validation_1-auc:0.83066
# [8]	validation_0-auc:0.85639	validation_1-auc:0.83275
# [9]	validation_0-auc:0.85728	validation_1-auc:0.83017
# [10]	validation_0-auc:0.86269	validation_1-auc:0.83533
# [11]	validation_0-auc:0.86281	validation_1-auc:0.83355
# [12]	validation_0-auc:0.86705	validation_1-auc:0.83545
# [13]	validation_0-auc:0.86914	validation_1-auc:0.83643
# [14]	validation_0-auc:0.87079	validation_1-auc:0.83671
# [15]	validation_0-auc:0.87185	validation_1-auc:0.83657
# [16]	validation_0-auc:0.87411	validation_1-auc:0.83759
# [17]	validation_0-auc:0.87594	validation_1-auc:0.83768
# [18]	validation_0-auc:0.87680	validation_1-auc:0.83745
# [19]	validation_0-auc:0.87782	validation_1-auc:0.83718
# [20]	validation_0-auc:0.87805	validation_1-auc:0.83735
# [21]	validation_0-auc:0.87913	validation_1-auc:0.83686
# [22]	validation_0-auc:0.87982	validation_1-auc:0.83744
# [23]	validation_0-auc:0.88090	validation_1-auc:0.83654
# [24]	validation_0-auc:0.88195	validation_1-auc:0.83607
# [25]	validation_0-auc:0.88253	validation_1-auc:0.83678
# [26]	validation_0-auc:0.88272	validation_1-auc:0.83657
# [27]	validation_0-auc:0.88361	validation_1-auc:0.83638
# [28]	validation_0-auc:0.88380	validation_1-auc:0.83630
# [29]	validation_0-auc:0.88442	validation_1-auc:0.83620
# [30]	validation_0-auc:0.88525	validation_1-auc:0.83620
# [31]	validation_0-auc:0.88601	validation_1-auc:0.83618
# [32]	validation_0-auc:0.88605	validation_1-auc:0.83596
# [33]	validation_0-auc:0.88637	validation_1-auc:0.83603
# [34]	validation_0-auc:0.88644	validation_1-auc:0.83584
# [35]	validation_0-auc:0.88665	validation_1-auc:0.83534
# [36]	validation_0-auc:0.88677	validation_1-auc:0.83486
# [37]	validation_0-auc:0.88721	validation_1-auc:0.83453
# [38]	validation_0-auc:0.88814	validation_1-auc:0.83492
# [39]	validation_0-auc:0.88958	validation_1-auc:0.83468
# [40]	validation_0-auc:0.89023	validation_1-auc:0.83488
# [41]	validation_0-auc:0.89077	validation_1-auc:0.83459
# [42]	validation_0-auc:0.89165	validation_1-auc:0.83319
# [43]	validation_0-auc:0.89166	validation_1-auc:0.83291
# [44]	validation_0-auc:0.89185	validation_1-auc:0.83286
# [45]	validation_0-auc:0.89188	validation_1-auc:0.83248
# [46]	validation_0-auc:0.89193	validation_1-auc:0.83229
# [00:20:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { n_estimator } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation_0-auc:0.80630	validation_1-auc:0.80915
# [1]	validation_0-auc:0.81874	validation_1-auc:0.81898
# [2]	validation_0-auc:0.82804	validation_1-auc:0.82321
# [3]	validation_0-auc:0.82973	validation_1-auc:0.82175
# [4]	validation_0-auc:0.83369	validation_1-auc:0.82338
# [5]	validation_0-auc:0.83740	validation_1-auc:0.82870
# [6]	validation_0-auc:0.84076	validation_1-auc:0.83170
# [7]	validation_0-auc:0.84413	validation_1-auc:0.83410
# [8]	validation_0-auc:0.84591	validation_1-auc:0.83585
# [9]	validation_0-auc:0.84936	validation_1-auc:0.83604
# [10]	validation_0-auc:0.85016	validation_1-auc:0.83716
# [11]	validation_0-auc:0.85281	validation_1-auc:0.83623
# [12]	validation_0-auc:0.85514	validation_1-auc:0.83666
# [13]	validation_0-auc:0.85689	validation_1-auc:0.83613
# [14]	validation_0-auc:0.85757	validation_1-auc:0.83555
# [15]	validation_0-auc:0.85933	validation_1-auc:0.83557
# [16]	validation_0-auc:0.86124	validation_1-auc:0.83492
# [17]	validation_0-auc:0.86226	validation_1-auc:0.83506
# [18]	validation_0-auc:0.86396	validation_1-auc:0.83599
# [19]	validation_0-auc:0.86488	validation_1-auc:0.83559
# [20]	validation_0-auc:0.86662	validation_1-auc:0.83574
# [21]	validation_0-auc:0.86730	validation_1-auc:0.83486
# [22]	validation_0-auc:0.86793	validation_1-auc:0.83469
# [23]	validation_0-auc:0.86945	validation_1-auc:0.83497
# [24]	validation_0-auc:0.87012	validation_1-auc:0.83386
# [25]	validation_0-auc:0.87028	validation_1-auc:0.83398
# [26]	validation_0-auc:0.87050	validation_1-auc:0.83357
# [27]	validation_0-auc:0.87118	validation_1-auc:0.83320
# [28]	validation_0-auc:0.87145	validation_1-auc:0.83300
# [29]	validation_0-auc:0.87188	validation_1-auc:0.83206
# [30]	validation_0-auc:0.87291	validation_1-auc:0.83190
# [31]	validation_0-auc:0.87349	validation_1-auc:0.83187
# [32]	validation_0-auc:0.87374	validation_1-auc:0.83207
# [33]	validation_0-auc:0.87430	validation_1-auc:0.83239
# [34]	validation_0-auc:0.87458	validation_1-auc:0.83304
# [35]	validation_0-auc:0.87507	validation_1-auc:0.83295
# [36]	validation_0-auc:0.87520	validation_1-auc:0.83279
# [37]	validation_0-auc:0.87529	validation_1-auc:0.83264
# [38]	validation_0-auc:0.87648	validation_1-auc:0.83387
# [39]	validation_0-auc:0.87663	validation_1-auc:0.83313
# [00:21:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { n_estimator } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation_0-auc:0.80886	validation_1-auc:0.80042
# [1]	validation_0-auc:0.82208	validation_1-auc:0.81713
# [2]	validation_0-auc:0.82607	validation_1-auc:0.81626
# [3]	validation_0-auc:0.83296	validation_1-auc:0.82504
# [4]	validation_0-auc:0.83835	validation_1-auc:0.82855
# [5]	validation_0-auc:0.83953	validation_1-auc:0.82886
# [6]	validation_0-auc:0.84250	validation_1-auc:0.83270
# [7]	validation_0-auc:0.84530	validation_1-auc:0.83438
# [8]	validation_0-auc:0.84785	validation_1-auc:0.83725
# [9]	validation_0-auc:0.84968	validation_1-auc:0.83755
# [10]	validation_0-auc:0.85073	validation_1-auc:0.83754
# [11]	validation_0-auc:0.85390	validation_1-auc:0.83811
# [12]	validation_0-auc:0.85609	validation_1-auc:0.83796
# [13]	validation_0-auc:0.85745	validation_1-auc:0.84000
# [14]	validation_0-auc:0.85908	validation_1-auc:0.84119
# [15]	validation_0-auc:0.86076	validation_1-auc:0.84181
# [16]	validation_0-auc:0.86248	validation_1-auc:0.84221
# [17]	validation_0-auc:0.86342	validation_1-auc:0.84175
# [18]	validation_0-auc:0.86486	validation_1-auc:0.84166
# [19]	validation_0-auc:0.86554	validation_1-auc:0.84149
# [20]	validation_0-auc:0.86600	validation_1-auc:0.84205
# [21]	validation_0-auc:0.86754	validation_1-auc:0.84107
# [22]	validation_0-auc:0.86834	validation_1-auc:0.84023
# [23]	validation_0-auc:0.86887	validation_1-auc:0.84039
# [24]	validation_0-auc:0.86941	validation_1-auc:0.84046
# [25]	validation_0-auc:0.86978	validation_1-auc:0.84035
# [26]	validation_0-auc:0.87033	validation_1-auc:0.83998
# [27]	validation_0-auc:0.87057	validation_1-auc:0.83974
# [28]	validation_0-auc:0.87073	validation_1-auc:0.83980
# [29]	validation_0-auc:0.87189	validation_1-auc:0.83913
# [30]	validation_0-auc:0.87308	validation_1-auc:0.83879
# [31]	validation_0-auc:0.87418	validation_1-auc:0.83868
# [32]	validation_0-auc:0.87457	validation_1-auc:0.83840
# [33]	validation_0-auc:0.87521	validation_1-auc:0.83791
# [34]	validation_0-auc:0.87538	validation_1-auc:0.83799
# [35]	validation_0-auc:0.87597	validation_1-auc:0.83800
# [36]	validation_0-auc:0.87595	validation_1-auc:0.83800
# [37]	validation_0-auc:0.87629	validation_1-auc:0.83800
# [38]	validation_0-auc:0.87718	validation_1-auc:0.83760
# [39]	validation_0-auc:0.87732	validation_1-auc:0.83758
# [40]	validation_0-auc:0.87749	validation_1-auc:0.83750
# [41]	validation_0-auc:0.87763	validation_1-auc:0.83730
# [42]	validation_0-auc:0.87787	validation_1-auc:0.83732
# [43]	validation_0-auc:0.87886	validation_1-auc:0.83718
# [44]	validation_0-auc:0.87901	validation_1-auc:0.83692
# [45]	validation_0-auc:0.87944	validation_1-auc:0.83673
# [00:21:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { n_estimator } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation_0-auc:0.81985	validation_1-auc:0.81832
# [1]	validation_0-auc:0.82510	validation_1-auc:0.82263
# [2]	validation_0-auc:0.82842	validation_1-auc:0.82621
# [3]	validation_0-auc:0.83222	validation_1-auc:0.82619
# [4]	validation_0-auc:0.83614	validation_1-auc:0.82572
# [5]	validation_0-auc:0.84103	validation_1-auc:0.83104
# [6]	validation_0-auc:0.84259	validation_1-auc:0.83476
# [7]	validation_0-auc:0.84418	validation_1-auc:0.83540
# [8]	validation_0-auc:0.84500	validation_1-auc:0.83467
# [9]	validation_0-auc:0.84824	validation_1-auc:0.83361
# [10]	validation_0-auc:0.85090	validation_1-auc:0.83665
# [11]	validation_0-auc:0.85289	validation_1-auc:0.83798
# [12]	validation_0-auc:0.85463	validation_1-auc:0.83950
# [13]	validation_0-auc:0.85688	validation_1-auc:0.83963
# [14]	validation_0-auc:0.85872	validation_1-auc:0.83975
# [15]	validation_0-auc:0.86000	validation_1-auc:0.83977
# [16]	validation_0-auc:0.86133	validation_1-auc:0.83946
# [17]	validation_0-auc:0.86210	validation_1-auc:0.83990
# [18]	validation_0-auc:0.86311	validation_1-auc:0.83869
# [19]	validation_0-auc:0.86470	validation_1-auc:0.83842
# [20]	validation_0-auc:0.86650	validation_1-auc:0.83933
# [21]	validation_0-auc:0.86702	validation_1-auc:0.83875
# [22]	validation_0-auc:0.86823	validation_1-auc:0.83844
# [23]	validation_0-auc:0.86859	validation_1-auc:0.83826
# [24]	validation_0-auc:0.86908	validation_1-auc:0.83836
# [25]	validation_0-auc:0.86956	validation_1-auc:0.83831
# [26]	validation_0-auc:0.87018	validation_1-auc:0.83784
# [27]	validation_0-auc:0.87076	validation_1-auc:0.83793
# [28]	validation_0-auc:0.87102	validation_1-auc:0.83776
# [29]	validation_0-auc:0.87187	validation_1-auc:0.83746
# [30]	validation_0-auc:0.87260	validation_1-auc:0.83675
# [31]	validation_0-auc:0.87314	validation_1-auc:0.83668
# [32]	validation_0-auc:0.87332	validation_1-auc:0.83665
# [33]	validation_0-auc:0.87396	validation_1-auc:0.83666
# [34]	validation_0-auc:0.87452	validation_1-auc:0.83628
# [35]	validation_0-auc:0.87450	validation_1-auc:0.83657
# [36]	validation_0-auc:0.87559	validation_1-auc:0.83701
# [37]	validation_0-auc:0.87572	validation_1-auc:0.83697
# [38]	validation_0-auc:0.87651	validation_1-auc:0.83644
# [39]	validation_0-auc:0.87669	validation_1-auc:0.83628
# [40]	validation_0-auc:0.87736	validation_1-auc:0.83698
# [41]	validation_0-auc:0.87753	validation_1-auc:0.83767
# [42]	validation_0-auc:0.87777	validation_1-auc:0.83744
# [43]	validation_0-auc:0.87796	validation_1-auc:0.83688
# [44]	validation_0-auc:0.87819	validation_1-auc:0.83637
# [45]	validation_0-auc:0.87984	validation_1-auc:0.83595
# [46]	validation_0-auc:0.88047	validation_1-auc:0.83569
# [47]	validation_0-auc:0.88094	validation_1-auc:0.83523
# [00:21:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { n_estimator } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation_0-auc:0.80799	validation_1-auc:0.80812
# [1]	validation_0-auc:0.81831	validation_1-auc:0.81961
# [2]	validation_0-auc:0.82748	validation_1-auc:0.82708
# [3]	validation_0-auc:0.82911	validation_1-auc:0.82664
# [4]	validation_0-auc:0.83361	validation_1-auc:0.82846
# [5]	validation_0-auc:0.83832	validation_1-auc:0.82989
# [6]	validation_0-auc:0.84076	validation_1-auc:0.83097
# [7]	validation_0-auc:0.84354	validation_1-auc:0.83384
# [8]	validation_0-auc:0.84566	validation_1-auc:0.83589
# [9]	validation_0-auc:0.84792	validation_1-auc:0.83697
# [10]	validation_0-auc:0.84881	validation_1-auc:0.83836
# [11]	validation_0-auc:0.85245	validation_1-auc:0.83818
# [12]	validation_0-auc:0.85402	validation_1-auc:0.83798
# [13]	validation_0-auc:0.85507	validation_1-auc:0.83847
# [14]	validation_0-auc:0.85616	validation_1-auc:0.83786
# [15]	validation_0-auc:0.85732	validation_1-auc:0.83780
# [16]	validation_0-auc:0.85865	validation_1-auc:0.83886
# [17]	validation_0-auc:0.85951	validation_1-auc:0.83921
# [18]	validation_0-auc:0.85997	validation_1-auc:0.83922
# [19]	validation_0-auc:0.86142	validation_1-auc:0.83986
# [20]	validation_0-auc:0.86234	validation_1-auc:0.84020
# [21]	validation_0-auc:0.86277	validation_1-auc:0.83960
# [22]	validation_0-auc:0.86353	validation_1-auc:0.83929
# [23]	validation_0-auc:0.86446	validation_1-auc:0.83926
# [24]	validation_0-auc:0.86459	validation_1-auc:0.83932
# [25]	validation_0-auc:0.86566	validation_1-auc:0.83825
# [26]	validation_0-auc:0.86647	validation_1-auc:0.83746
# [27]	validation_0-auc:0.86664	validation_1-auc:0.83740
# [28]	validation_0-auc:0.86679	validation_1-auc:0.83740
# [29]	validation_0-auc:0.86703	validation_1-auc:0.83794
# [30]	validation_0-auc:0.86756	validation_1-auc:0.83707
# [31]	validation_0-auc:0.86877	validation_1-auc:0.83674
# [32]	validation_0-auc:0.86893	validation_1-auc:0.83697
# [33]	validation_0-auc:0.86941	validation_1-auc:0.83684
# [34]	validation_0-auc:0.86973	validation_1-auc:0.83629
# [35]	validation_0-auc:0.86986	validation_1-auc:0.83620
# [36]	validation_0-auc:0.86984	validation_1-auc:0.83642
# [37]	validation_0-auc:0.87113	validation_1-auc:0.83534
# [38]	validation_0-auc:0.87232	validation_1-auc:0.83547
# [39]	validation_0-auc:0.87231	validation_1-auc:0.83561
# [40]	validation_0-auc:0.87278	validation_1-auc:0.83543
# [41]	validation_0-auc:0.87364	validation_1-auc:0.83414
# [42]	validation_0-auc:0.87412	validation_1-auc:0.83466
# [43]	validation_0-auc:0.87487	validation_1-auc:0.83399
# [44]	validation_0-auc:0.87498	validation_1-auc:0.83390
# [45]	validation_0-auc:0.87512	validation_1-auc:0.83360
# [46]	validation_0-auc:0.87539	validation_1-auc:0.83342
# [47]	validation_0-auc:0.87545	validation_1-auc:0.83340
# [48]	validation_0-auc:0.87565	validation_1-auc:0.83319
# [49]	validation_0-auc:0.87592	validation_1-auc:0.83325
# [50]	validation_0-auc:0.87587	validation_1-auc:0.83307
# [00:21:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { n_estimator } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
# ...
# [26]	validation_0-auc:0.88920	validation_1-auc:0.83853
# [27]	validation_0-auc:0.88939	validation_1-auc:0.83826
# [28]	validation_0-auc:0.88941	validation_1-auc:0.83841
# [29]	validation_0-auc:0.89046	validation_1-auc:0.83798
# [30]	validation_0-auc:0.89124	validation_1-auc:0.83721
# [31]	validation_0-auc:0.89249	validation_1-auc:0.83774
# [32]	validation_0-auc:0.89308	validation_1-auc:0.83732
# [33]	validation_0-auc:0.89381	validation_1-auc:0.83673
# [34]	validation_0-auc:0.89470	validation_1-auc:0.83640
# [35]	validation_0-auc:0.89503	validation_1-auc:0.83638
# [36]	validation_0-auc:0.89522	validation_1-auc:0.83645
# [37]	validation_0-auc:0.89562	validation_1-auc:0.83598
# [38]	validation_0-auc:0.89606	validation_1-auc:0.83589
# [39]	validation_0-auc:0.89668	validation_1-auc:0.83503
# [40]	validation_0-auc:0.89765	validation_1-auc:0.83505
# [41]	validation_0-auc:0.89772	validation_1-auc:0.83494
# [42]	validation_0-auc:0.89826	validation_1-auc:0.83472
# [43]	validation_0-auc:0.89824	validation_1-auc:0.83470
# [44]	validation_0-auc:0.89835	validation_1-auc:0.83480
# [45]	validation_0-auc:0.89847	validation_1-auc:0.83458
# [46]	validation_0-auc:0.89955	validation_1-auc:0.83422
# [47]	validation_0-auc:0.89963	validation_1-auc:0.83422
# [48]	validation_0-auc:0.89988	validation_1-auc:0.83370
# [49]	validation_0-auc:0.89992	validation_1-auc:0.83356
# [50]	validation_0-auc:0.90047	validation_1-auc:0.83258
# [51]	validation_0-auc:0.90176	validation_1-auc:0.83157
# [52]	validation_0-auc:0.90206	validation_1-auc:0.83090
# [00:22:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { n_estimator } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation_0-auc:0.82514	validation_1-auc:0.82020
# [1]	validation_0-auc:0.83138	validation_1-auc:0.82522
# [2]	validation_0-auc:0.83700	validation_1-auc:0.82681
# [3]	validation_0-auc:0.84082	validation_1-auc:0.82715
# [4]	validation_0-auc:0.84552	validation_1-auc:0.82905
# [5]	validation_0-auc:0.85242	validation_1-auc:0.83197
# [6]	validation_0-auc:0.85485	validation_1-auc:0.83441
# [7]	validation_0-auc:0.85792	validation_1-auc:0.83625
# [8]	validation_0-auc:0.86187	validation_1-auc:0.83512
# [9]	validation_0-auc:0.86781	validation_1-auc:0.83440
# [10]	validation_0-auc:0.87077	validation_1-auc:0.83639
# [11]	validation_0-auc:0.87192	validation_1-auc:0.83735
# [12]	validation_0-auc:0.87535	validation_1-auc:0.83720
# [13]	validation_0-auc:0.87841	validation_1-auc:0.83732
# [14]	validation_0-auc:0.87998	validation_1-auc:0.83692
# [15]	validation_0-auc:0.88158	validation_1-auc:0.83757
# [16]	validation_0-auc:0.88271	validation_1-auc:0.83887
# [17]	validation_0-auc:0.88479	validation_1-auc:0.83702
# [18]	validation_0-auc:0.88637	validation_1-auc:0.83689
# [19]	validation_0-auc:0.88767	validation_1-auc:0.83661
# [20]	validation_0-auc:0.88834	validation_1-auc:0.83765
# [21]	validation_0-auc:0.88944	validation_1-auc:0.83688
# [22]	validation_0-auc:0.89033	validation_1-auc:0.83639
# [23]	validation_0-auc:0.89171	validation_1-auc:0.83557
# [24]	validation_0-auc:0.89207	validation_1-auc:0.83522
# [25]	validation_0-auc:0.89278	validation_1-auc:0.83533
# [26]	validation_0-auc:0.89307	validation_1-auc:0.83505
# [27]	validation_0-auc:0.89304	validation_1-auc:0.83503
# [28]	validation_0-auc:0.89375	validation_1-auc:0.83480
# [29]	validation_0-auc:0.89438	validation_1-auc:0.83494
# [30]	validation_0-auc:0.89523	validation_1-auc:0.83473
# [31]	validation_0-auc:0.89614	validation_1-auc:0.83412
# [32]	validation_0-auc:0.89619	validation_1-auc:0.83387
# [33]	validation_0-auc:0.89636	validation_1-auc:0.83410
# [34]	validation_0-auc:0.89665	validation_1-auc:0.83467
# [35]	validation_0-auc:0.89675	validation_1-auc:0.83466
# [36]	validation_0-auc:0.89722	validation_1-auc:0.83469
# [37]	validation_0-auc:0.89758	validation_1-auc:0.83476
# [38]	validation_0-auc:0.89782	validation_1-auc:0.83485
# [39]	validation_0-auc:0.89787	validation_1-auc:0.83462
# [40]	validation_0-auc:0.89808	validation_1-auc:0.83471
# [41]	validation_0-auc:0.89811	validation_1-auc:0.83456
# [42]	validation_0-auc:0.89826	validation_1-auc:0.83342
# [43]	validation_0-auc:0.89900	validation_1-auc:0.83276
# [44]	validation_0-auc:0.89989	validation_1-auc:0.83183
# [45]	validation_0-auc:0.90033	validation_1-auc:0.83176
# [46]	validation_0-auc:0.90033	validation_1-auc:0.83171
# [00:22:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { n_estimator } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation_0-auc:0.81623	validation_1-auc:0.81170
# [1]	validation_0-auc:0.82774	validation_1-auc:0.82626
# [2]	validation_0-auc:0.83422	validation_1-auc:0.82798
# [3]	validation_0-auc:0.83758	validation_1-auc:0.82687
# [4]	validation_0-auc:0.84235	validation_1-auc:0.83010
# [5]	validation_0-auc:0.84789	validation_1-auc:0.83480
# [6]	validation_0-auc:0.85162	validation_1-auc:0.83628
# [7]	validation_0-auc:0.85390	validation_1-auc:0.83693
# [8]	validation_0-auc:0.85753	validation_1-auc:0.83765
# [9]	validation_0-auc:0.85902	validation_1-auc:0.83624
# [10]	validation_0-auc:0.86184	validation_1-auc:0.83618
# [11]	validation_0-auc:0.86450	validation_1-auc:0.83517
# [12]	validation_0-auc:0.86804	validation_1-auc:0.83475
# [13]	validation_0-auc:0.86997	validation_1-auc:0.83613
# [14]	validation_0-auc:0.87096	validation_1-auc:0.83544
# [15]	validation_0-auc:0.87224	validation_1-auc:0.83438
# [16]	validation_0-auc:0.87448	validation_1-auc:0.83540
# [17]	validation_0-auc:0.87465	validation_1-auc:0.83523
# [18]	validation_0-auc:0.87581	validation_1-auc:0.83429
# [19]	validation_0-auc:0.87643	validation_1-auc:0.83467
# [20]	validation_0-auc:0.87727	validation_1-auc:0.83505
# [21]	validation_0-auc:0.87736	validation_1-auc:0.83498
# [22]	validation_0-auc:0.87866	validation_1-auc:0.83448
# [23]	validation_0-auc:0.87923	validation_1-auc:0.83422
# [24]	validation_0-auc:0.87935	validation_1-auc:0.83428
# [25]	validation_0-auc:0.87993	validation_1-auc:0.83381
# [26]	validation_0-auc:0.88081	validation_1-auc:0.83412
# [27]	validation_0-auc:0.88172	validation_1-auc:0.83424
# [28]	validation_0-auc:0.88182	validation_1-auc:0.83427
# [29]	validation_0-auc:0.88219	validation_1-auc:0.83364
# [30]	validation_0-auc:0.88246	validation_1-auc:0.83352
# [31]	validation_0-auc:0.88253	validation_1-auc:0.83336
# [32]	validation_0-auc:0.88292	validation_1-auc:0.83229
# [33]	validation_0-auc:0.88311	validation_1-auc:0.83263
# [34]	validation_0-auc:0.88362	validation_1-auc:0.83203
# [35]	validation_0-auc:0.88417	validation_1-auc:0.83174
# [36]	validation_0-auc:0.88449	validation_1-auc:0.83179
# [37]	validation_0-auc:0.88451	validation_1-auc:0.83155
# [38]	validation_0-auc:0.88451	validation_1-auc:0.83145
# [00:23:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { n_estimator } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation_0-auc:0.81220	validation_1-auc:0.80604
# [1]	validation_0-auc:0.82510	validation_1-auc:0.81832
# [2]	validation_0-auc:0.83511	validation_1-auc:0.82342
# [3]	validation_0-auc:0.83949	validation_1-auc:0.82527
# [4]	validation_0-auc:0.84579	validation_1-auc:0.82797
# [5]	validation_0-auc:0.85209	validation_1-auc:0.83164
# [6]	validation_0-auc:0.85476	validation_1-auc:0.83171
# [7]	validation_0-auc:0.85794	validation_1-auc:0.83576
# [8]	validation_0-auc:0.86169	validation_1-auc:0.83746
# [9]	validation_0-auc:0.86370	validation_1-auc:0.83800
# [10]	validation_0-auc:0.86570	validation_1-auc:0.83877
# [11]	validation_0-auc:0.86908	validation_1-auc:0.83814
# [12]	validation_0-auc:0.87121	validation_1-auc:0.83988
# [13]	validation_0-auc:0.87336	validation_1-auc:0.83933
# [14]	validation_0-auc:0.87444	validation_1-auc:0.83935
# [15]	validation_0-auc:0.87548	validation_1-auc:0.83974
# [16]	validation_0-auc:0.87745	validation_1-auc:0.83907
# [17]	validation_0-auc:0.87798	validation_1-auc:0.83941
# [18]	validation_0-auc:0.88003	validation_1-auc:0.83859
# [19]	validation_0-auc:0.88086	validation_1-auc:0.83820
# [20]	validation_0-auc:0.88110	validation_1-auc:0.83820
# [21]	validation_0-auc:0.88141	validation_1-auc:0.83791
# [22]	validation_0-auc:0.88200	validation_1-auc:0.83804
# [23]	validation_0-auc:0.88356	validation_1-auc:0.83755
# [24]	validation_0-auc:0.88368	validation_1-auc:0.83759
# [25]	validation_0-auc:0.88495	validation_1-auc:0.83609
# [26]	validation_0-auc:0.88507	validation_1-auc:0.83594
# [27]	validation_0-auc:0.88578	validation_1-auc:0.83591
# [28]	validation_0-auc:0.88589	validation_1-auc:0.83602
# [29]	validation_0-auc:0.88619	validation_1-auc:0.83608
# [30]	validation_0-auc:0.88686	validation_1-auc:0.83566
# [31]	validation_0-auc:0.88718	validation_1-auc:0.83544
# [32]	validation_0-auc:0.88755	validation_1-auc:0.83557
# [33]	validation_0-auc:0.88781	validation_1-auc:0.83553
# [34]	validation_0-auc:0.88814	validation_1-auc:0.83526
# [35]	validation_0-auc:0.88828	validation_1-auc:0.83500
# [36]	validation_0-auc:0.88831	validation_1-auc:0.83486
# [37]	validation_0-auc:0.88844	validation_1-auc:0.83483
# [38]	validation_0-auc:0.88850	validation_1-auc:0.83470
# [39]	validation_0-auc:0.88898	validation_1-auc:0.83477
# [40]	validation_0-auc:0.88901	validation_1-auc:0.83437
# [41]	validation_0-auc:0.88900	validation_1-auc:0.83481
# [42]	validation_0-auc:0.88907	validation_1-auc:0.83494
# [00:23:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { n_estimator } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation_0-auc:0.82350	validation_1-auc:0.81796
# [1]	validation_0-auc:0.83103	validation_1-auc:0.82195
# [2]	validation_0-auc:0.83941	validation_1-auc:0.82811
# [3]	validation_0-auc:0.84356	validation_1-auc:0.82990
# [4]	validation_0-auc:0.84674	validation_1-auc:0.83063
# [5]	validation_0-auc:0.85167	validation_1-auc:0.83177
# [6]	validation_0-auc:0.85426	validation_1-auc:0.83289
# [7]	validation_0-auc:0.85756	validation_1-auc:0.83383
# [8]	validation_0-auc:0.85949	validation_1-auc:0.83361
# [9]	validation_0-auc:0.86363	validation_1-auc:0.83399
# [10]	validation_0-auc:0.86665	validation_1-auc:0.83484
# [11]	validation_0-auc:0.86934	validation_1-auc:0.83660
# [12]	validation_0-auc:0.87280	validation_1-auc:0.83565
# [13]	validation_0-auc:0.87349	validation_1-auc:0.83766
# [14]	validation_0-auc:0.87509	validation_1-auc:0.83625
# [15]	validation_0-auc:0.87643	validation_1-auc:0.83595
# [16]	validation_0-auc:0.87714	validation_1-auc:0.83624
# [17]	validation_0-auc:0.87822	validation_1-auc:0.83588
# [18]	validation_0-auc:0.87942	validation_1-auc:0.83485
# [19]	validation_0-auc:0.88023	validation_1-auc:0.83448
# [20]	validation_0-auc:0.88114	validation_1-auc:0.83400
# [21]	validation_0-auc:0.88190	validation_1-auc:0.83397
# [22]	validation_0-auc:0.88296	validation_1-auc:0.83435
# [23]	validation_0-auc:0.88318	validation_1-auc:0.83400
# [24]	validation_0-auc:0.88356	validation_1-auc:0.83500
# [25]	validation_0-auc:0.88413	validation_1-auc:0.83503
# [26]	validation_0-auc:0.88428	validation_1-auc:0.83510
# [27]	validation_0-auc:0.88457	validation_1-auc:0.83449
# [28]	validation_0-auc:0.88530	validation_1-auc:0.83485
# [29]	validation_0-auc:0.88561	validation_1-auc:0.83478
# [30]	validation_0-auc:0.88652	validation_1-auc:0.83474
# [31]	validation_0-auc:0.88682	validation_1-auc:0.83443
# [32]	validation_0-auc:0.88799	validation_1-auc:0.83405
# [33]	validation_0-auc:0.88828	validation_1-auc:0.83370
# [34]	validation_0-auc:0.88852	validation_1-auc:0.83339
# [35]	validation_0-auc:0.88874	validation_1-auc:0.83284
# [36]	validation_0-auc:0.88943	validation_1-auc:0.83213
# [37]	validation_0-auc:0.88972	validation_1-auc:0.83177
# [38]	validation_0-auc:0.89014	validation_1-auc:0.83115
# [39]	validation_0-auc:0.89042	validation_1-auc:0.83090
# [40]	validation_0-auc:0.89052	validation_1-auc:0.83085
# [41]	validation_0-auc:0.89060	validation_1-auc:0.83069
# [42]	validation_0-auc:0.89067	validation_1-auc:0.83049
# [43]	validation_0-auc:0.89137	validation_1-auc:0.83012
# [00:23:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { n_estimator } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation_0-auc:0.81760	validation_1-auc:0.81179
# [1]	validation_0-auc:0.82687	validation_1-auc:0.82086
# [2]	validation_0-auc:0.82998	validation_1-auc:0.81895
# [3]	validation_0-auc:0.83603	validation_1-auc:0.82538
# [4]	validation_0-auc:0.83951	validation_1-auc:0.82824
# [5]	validation_0-auc:0.84296	validation_1-auc:0.83196
# [6]	validation_0-auc:0.84680	validation_1-auc:0.83452
# [7]	validation_0-auc:0.84967	validation_1-auc:0.83570
# [8]	validation_0-auc:0.85133	validation_1-auc:0.83635
# [9]	validation_0-auc:0.85394	validation_1-auc:0.83733
# [10]	validation_0-auc:0.85569	validation_1-auc:0.83923
# [11]	validation_0-auc:0.85781	validation_1-auc:0.84026
# [12]	validation_0-auc:0.86072	validation_1-auc:0.84141
# [13]	validation_0-auc:0.86203	validation_1-auc:0.84082
# [14]	validation_0-auc:0.86346	validation_1-auc:0.84078
# [15]	validation_0-auc:0.86513	validation_1-auc:0.84111
# [16]	validation_0-auc:0.86649	validation_1-auc:0.84116
# [17]	validation_0-auc:0.86883	validation_1-auc:0.84197
# [18]	validation_0-auc:0.87098	validation_1-auc:0.84205
# [19]	validation_0-auc:0.87193	validation_1-auc:0.84170
# [20]	validation_0-auc:0.87292	validation_1-auc:0.84190
# [21]	validation_0-auc:0.87368	validation_1-auc:0.84197
# [22]	validation_0-auc:0.87530	validation_1-auc:0.84242
# [23]	validation_0-auc:0.87581	validation_1-auc:0.84251
# [24]	validation_0-auc:0.87682	validation_1-auc:0.84246
# [25]	validation_0-auc:0.87832	validation_1-auc:0.84218
# [26]	validation_0-auc:0.87877	validation_1-auc:0.84190
# [27]	validation_0-auc:0.87913	validation_1-auc:0.84205
# [28]	validation_0-auc:0.87961	validation_1-auc:0.84189
# [29]	validation_0-auc:0.87994	validation_1-auc:0.84194
# [30]	validation_0-auc:0.88065	validation_1-auc:0.84166
# [31]	validation_0-auc:0.88158	validation_1-auc:0.84160
# [32]	validation_0-auc:0.88218	validation_1-auc:0.84168
# [33]	validation_0-auc:0.88289	validation_1-auc:0.84098
# [34]	validation_0-auc:0.88359	validation_1-auc:0.84024
# [35]	validation_0-auc:0.88384	validation_1-auc:0.84075
# [36]	validation_0-auc:0.88416	validation_1-auc:0.84086
# [37]	validation_0-auc:0.88431	validation_1-auc:0.84052
# [38]	validation_0-auc:0.88499	validation_1-auc:0.84043
# [39]	validation_0-auc:0.88540	validation_1-auc:0.84025
# [40]	validation_0-auc:0.88577	validation_1-auc:0.84046
# [41]	validation_0-auc:0.88681	validation_1-auc:0.84019
# [42]	validation_0-auc:0.88716	validation_1-auc:0.84005
# [43]	validation_0-auc:0.88739	validation_1-auc:0.84001
# [44]	validation_0-auc:0.88753	validation_1-auc:0.84030
# [45]	validation_0-auc:0.88787	validation_1-auc:0.84030
# [46]	validation_0-auc:0.88842	validation_1-auc:0.84054
# [47]	validation_0-auc:0.88913	validation_1-auc:0.84027
# [48]	validation_0-auc:0.89007	validation_1-auc:0.83959
# [49]	validation_0-auc:0.89046	validation_1-auc:0.83940
# [50]	validation_0-auc:0.89059	validation_1-auc:0.83950
# [51]	validation_0-auc:0.89138	validation_1-auc:0.83935
# [52]	validation_0-auc:0.89206	validation_1-auc:0.83897
# [53]	validation_0-auc:0.89290	validation_1-auc:0.83901
# GridSearchCV 최적 파라미터: {'colsample_bytree': 0.75, 'max_depth': 5, 'min_child_weight': 1}
# ROC AUC:0.8425
